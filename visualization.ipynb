# %%
import copy
from configuration import get_config
from utils import dropout_plot,results_visualization_l

threshold = 2000

config = get_config()
config['global_round']=2000

# %%
alg = ['FedAvg','FedAvg_v']
configs =[config for i in range(3)]
config1 = copy.deepcopy(config)
alg.extend(['FedProx','FedProx_v'])
configs.extend([config1 for i in range(2)])
seed_l = [777]
smoothed = 0
results_visualization_l(alg,configs,2000, seed_l,smoothed)

# %%
config1 = copy.deepcopy(config)
dropout_plot(config,config1,seed_l,threshold)
